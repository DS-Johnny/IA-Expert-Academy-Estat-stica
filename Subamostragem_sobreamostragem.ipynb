# %% [markdown]
# # Subamostragem e Sobreamostragem (Undersampling / Oversampling)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
